# %% [markdown]
# # Assingment_1

# %% [markdown]
# # 1. Write a Python program to print "Hello Python"

# %%
print("Hello Python")
# Out:
# Hello Python

# %% [markdown]
# # 2. Write a Python program to do arithmetical operations addition and division.?

# %%
a = 10
b = 20 

print("Addition {}+{} = {}".format(a,b,a+b))
print("Division {}+{} = {}".format(a,b,a/b))
# Out:
# Addition 10+20 = 30
# Division 10+20 = 0.5

# %% [markdown]
# # 3. Write a Python program to find the area of a triangle?

# %%
b = int(input("enter the base:"))
h = int(input("enter the height:"))

area = (b*h)/2

print("Area of the triangle =", area)
# Out:
# enter the base:5
# enter the height:7
# Area of the triangle = 17.5

# %% [markdown]
# # 4. Write a Python program to swap two variables

# %%
a = 10 
b = 20 

print("Berfore swaping a = {} , b = {}".format(a,b))

tempo = a 
a= b
b =tempo

print("After swaoing a = {} , b = {}".format(a,b))
# Out:
# Berfore swaping a = 10 , b = 20
# After swaoing a = 20 , b = 10

# %% [markdown]
# # 5. Write a Python program to generate a random number?

# %%
import random

randomnumber = random.randint(0,50)
print(randomnumber)
# Out:
# 43
